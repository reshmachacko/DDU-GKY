# %% [markdown]
# ## <center>CUISINE DATA ANALYSIS

# %% [markdown]
# #### Importing dependencies

# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Importing data

# %%
data=pd.read_csv('./Cuisine_rating.csv')
data
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 0          1        153  Upper East Side,NY  Female  2006         Single
# 1          2        123       St. George,NY  Female  1991        Married
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 3          4        153  Upper East Side,NY  Female  1956        Married
# 4          5        129     Central Park,NY    Male  1997         Single
# ..       ...        ...                 ...     ...   ...            ...
# 195      196        175       St. George,NY  Female  1982         Single
# 196      197        170  Upper West Side,NY  Female  2000        Married
# 197      198        160       St. George,NY  Female  2006         Single
# 198      199        130       St. George,NY    Male  2002        Married
# 199      200        140  Upper East Side,NY    Male  2005        Married
#
#          Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# ...

# %% [markdown]
# #### Checking basic informations and descriptions about data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   User ID         200 non-null    int64
#  1   Area code       200 non-null    int64
#  2   Location        200 non-null    object
#  3   Gender          200 non-null    object
#  4   YOB             200 non-null    int64
#  5   Marital Status  200 non-null    object
#  6   Activity        200 non-null    object
#  7   Budget          200 non-null    int64
#  8   Cuisines        200 non-null    object
#  9   Alcohol         200 non-null    object
#  10  Smoker          200 non-null    object
#  11  Food Rating     200 non-null    int64
#  12  Service Rating  200 non-null    int64
#  13  Overall Rating  200 non-null    float64
#  14  Often A S       200 non-null    object
# dtypes: float64(1), int64(6), object(8)
# memory usage: 23.6+ KB

# %%
data.describe()
# Out:
#           User ID   Area code          YOB      Budget  Food Rating  \
# count  200.000000  200.000000   200.000000  200.000000   200.000000
# mean   100.500000  141.060000  1984.830000    3.815000     3.220000
# std     57.879185   26.130257    16.809339    1.056578     1.411226
# min      1.000000  101.000000  1955.000000    1.000000     1.000000
# 25%     50.750000  123.000000  1971.000000    3.000000     2.000000
# 50%    100.500000  135.000000  1987.000000    4.000000     3.000000
# 75%    150.250000  158.000000  2000.000000    5.000000     5.000000
# max    200.000000  199.000000  2009.000000    5.000000     5.000000
#
#        Service Rating  Overall Rating
# count      200.000000      200.000000
# mean         3.230000        3.225000
# std          1.526022        1.079445
# min          1.000000        1.000000
# 25%          2.000000        2.500000
# 50%          3.000000        3.000000
# 75%          5.000000        4.000000
# max          5.000000        5.000000

# %%
data.shape
# Out:
# (200, 15)

# %%
data.columns
# Out:
# Index(['User ID', 'Area code', 'Location', 'Gender', 'YOB', 'Marital Status',
#        'Activity', 'Budget', 'Cuisines', 'Alcohol ', 'Smoker', 'Food Rating',
#        'Service Rating', 'Overall Rating', 'Often A S'],
#       dtype='object')

# %% [markdown]
# #### Dropping un necessary columns

# %%
data.drop(columns=['User ID','Area code'],inplace=True)
data.head()
# Out:
#              Location  Gender   YOB Marital Status      Activity  Budget  \
# 0  Upper East Side,NY  Female  2006         Single  Professional       3
# 1       St. George,NY  Female  1991        Married       Student       3
# 2  Upper West Side,NY    Male  1977         Single       Student       5
# 3  Upper East Side,NY  Female  1956        Married  Professional       5
# 4     Central Park,NY    Male  1997         Single       Student       4
#
#    Cuisines  Alcohol     Smoker  Food Rating  Service Rating  Overall Rating  \
# 0  Japanese     Never     Never            5               4             4.5
# 1    Indian     Never  Socially            1               1             1.0
# 2   Seafood     Often     Often            5               5             5.0
# 3  Japanese     Never  Socially            3               1             2.0
# 4  Filipino  Socially     Never            2               4             3.0
#
#   Often A S
# 0        No
# 1        No
# 2       Yes
# ...

# %% [markdown]
# #### Renaming columns

# %%
data.rename(columns={'Marital Status':'Marital_status','Alcohol ':'Alcohol','Food Rating':'Food_Rating','Service Rating':'Service_Rating','Overall Rating':'Overall_Rating','Often A S':'Often_A_S'},inplace=True)
data.head()
# Out:
#              Location  Gender   YOB Marital_status      Activity  Budget  \
# 0  Upper East Side,NY  Female  2006         Single  Professional       3
# 1       St. George,NY  Female  1991        Married       Student       3
# 2  Upper West Side,NY    Male  1977         Single       Student       5
# 3  Upper East Side,NY  Female  1956        Married  Professional       5
# 4     Central Park,NY    Male  1997         Single       Student       4
#
#    Cuisines   Alcohol    Smoker  Food_Rating  Service_Rating  Overall_Rating  \
# 0  Japanese     Never     Never            5               4             4.5
# 1    Indian     Never  Socially            1               1             1.0
# 2   Seafood     Often     Often            5               5             5.0
# 3  Japanese     Never  Socially            3               1             2.0
# 4  Filipino  Socially     Never            2               4             3.0
#
#   Often_A_S
# 0        No
# 1        No
# 2       Yes
# ...

# %% [markdown]
# #### Check for null values

# %%
data.isnull().mean()*100
# Out:
# Location          0.0
# Gender            0.0
# YOB               0.0
# Marital_status    0.0
# Activity          0.0
# Budget            0.0
# Cuisines          0.0
# Alcohol           0.0
# Smoker            0.0
# Food_Rating       0.0
# Service_Rating    0.0
# Overall_Rating    0.0
# Often_A_S         0.0
# dtype: float64

# %% [markdown]
# #### check for duplicated items and dropping it

# %%
data.duplicated().sum()
# Out:
# 79

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# #### Creating a new  age column with respect to YOB column

# %%
data['Age']=[(2022-YOB) for YOB in data['YOB']]
data.head()
# Out:
#              Location  Gender   YOB Marital_status      Activity  Budget  \
# 0  Upper East Side,NY  Female  2006         Single  Professional       3
# 1       St. George,NY  Female  1991        Married       Student       3
# 2  Upper West Side,NY    Male  1977         Single       Student       5
# 3  Upper East Side,NY  Female  1956        Married  Professional       5
# 4     Central Park,NY    Male  1997         Single       Student       4
#
#    Cuisines   Alcohol    Smoker  Food_Rating  Service_Rating  Overall_Rating  \
# 0  Japanese     Never     Never            5               4             4.5
# 1    Indian     Never  Socially            1               1             1.0
# 2   Seafood     Often     Often            5               5             5.0
# 3  Japanese     Never  Socially            3               1             2.0
# 4  Filipino  Socially     Never            2               4             3.0
#
#   Often_A_S  Age
# 0        No   16
# 1        No   31
# ...

# %% [markdown]
# #### Drop the YOB column

# %%
data.drop(columns='YOB',inplace=True)
data.head()
# Out:
#              Location  Gender Marital_status      Activity  Budget  Cuisines  \
# 0  Upper East Side,NY  Female         Single  Professional       3  Japanese
# 1       St. George,NY  Female        Married       Student       3    Indian
# 2  Upper West Side,NY    Male         Single       Student       5   Seafood
# 3  Upper East Side,NY  Female        Married  Professional       5  Japanese
# 4     Central Park,NY    Male         Single       Student       4  Filipino
#
#     Alcohol    Smoker  Food_Rating  Service_Rating  Overall_Rating Often_A_S  \
# 0     Never     Never            5               4             4.5        No
# 1     Never  Socially            1               1             1.0        No
# 2     Often     Often            5               5             5.0       Yes
# 3     Never  Socially            3               1             2.0        No
# 4  Socially     Never            2               4             3.0        No
#
#    Age
# 0   16
# 1   31
# 2   45
# ...

# %%
data.sample(20)
# Out:
#                Location  Gender Marital_status      Activity  Budget  \
# 15   Upper East Side,NY  Female        Married       Student       3
# 95        St. George,NY  Female         Single  Professional       4
# 100  Upper East Side,NY  Female         Single  Professional       3
# 14         Riverdale,NY    Male        Married       Student       3
# 112       St. George,NY  Female         Single  Professional       5
# 67      Market City, NY    Male        Married  Professional       3
# 38   Upper East Side,NY    Male        Married       Student       4
# 113        Riverdale,NY    Male         Single       Student       5
# 66       China Town, NY    Male         Single       Student       3
# 134     Central Park,NY    Male       Divorced       Student       1
# 89        St. George,NY    Male       Divorced  Professional       3
# 86        St. George,NY    Male        Married  Professional       4
# 28      Market City, NY  Female        Married       Student       4
# ...

# %% [markdown]
# #### Custom function to create location vise data frame

# %%
def sort_location(Location):
    data_Location=data[data.Location==Location]
    data_Location.drop(columns='Location',inplace=True)
    return data_Location

# %%
Upper_East_Side_NY=sort_location('Upper East Side,NY')
Upper_East_Side_NY
# Out:
#      Gender Marital_status      Activity  Budget  Cuisines   Alcohol  \
# 0    Female         Single  Professional       3  Japanese     Never
# 3    Female        Married  Professional       5  Japanese     Never
# 7    Female         Single  Professional       3  Filipino     Often
# 15   Female        Married       Student       3    French     Often
# 17     Male         Single       Student       3  Japanese     Often
# 21   Female        Married  Professional       5   Italian  Socially
# 38     Male        Married       Student       4    French     Never
# 51   Female         Single       Student       3   Chinese     Often
# 52   Female         Single  Professional       4   Chinese     Never
# 63   Female        Married       Student       5   Italian     Never
# 73     Male        Married       Student       3    Indian     Often
# 77     Male         Single       Student       5   Chinese  Socially
# 81     Male        Married  Professional       4   Chinese     Often
# ...

# %% [markdown]
# ## Descriptive EDA

# %% [markdown]
# #### 1. Top 10 restuarants with highest overall rating

# %%
data.nlargest(10,'Overall_Rating')
# Out:
#               Location  Gender Marital_status      Activity  Budget  Cuisines  \
# 2   Upper West Side,NY    Male         Single       Student       5   Seafood
# 12       St. George,NY  Female         Single  Professional       5   Chinese
# 23     Market City, NY    Male       Divorced  Professional       1   Seafood
# 34     Central Park,NY    Male       Divorced       Student       1  Japanese
# 41     Market City, NY  Female         Single       Student       5  Filipino
# 50        Riverdale,NY  Female         Single       Student       4  Japanese
# 56       St. George,NY  Female       Divorced       Student       2   Italian
# 61  Upper West Side,NY  Female       Divorced  Professional       4  Japanese
# 62       St. George,NY    Male         Single       Student       4  Japanese
# 64     Central Park,NY  Female         Single       Student       4   Italian
#
#      Alcohol    Smoker  Food_Rating  Service_Rating  Overall_Rating Often_A_S  \
# ...

# %% [markdown]
# #### 2. Top 3 indian cuisine restaurants in dataset	 with  highest food rating

# %%
data.query("Cuisines=='Indian'").nlargest(3,'Food_Rating')
# Out:
#            Location  Gender Marital_status      Activity  Budget Cuisines  \
# 20    St. George,NY  Female         Single       Student       3   Indian
# 67  Market City, NY    Male        Married  Professional       3   Indian
# 89    St. George,NY    Male       Divorced  Professional       3   Indian
#
#      Alcohol Smoker  Food_Rating  Service_Rating  Overall_Rating Often_A_S  \
# 20  Socially  Often            5               3             4.0        No
# 67     Never  Often            5               2             3.5        No
# 89     Often  Often            5               5             5.0       Yes
#
#     Age
# 20   13
# 67   22
# 89   34

# %% [markdown]
# #### 3. Average food  rating for each cuisines

# %%
fud_rating_cuisines=data.groupby(['Cuisines'])['Food_Rating'].mean()
fud_rating_cuisines
# Out:
# Cuisines
# Chinese     3.642857
# Filipino    2.736842
# French      3.277778
# Indian      2.727273
# Italian     3.454545
# Japanese    3.739130
# Seafood     3.357143
# Name: Food_Rating, dtype: float64

# %% [markdown]
# #### 4. Which are the most repeting cuisines by female proffesionals in Upper East Side,NY

# %%
Upper_East_Side_NY.query("Activity=='Professional' & Gender=='Female'").Cuisines.value_counts()
# Out:
# Japanese    3
# Filipino    2
# Italian     1
# Chinese     1
# Name: Cuisines, dtype: int64

# %% [markdown]
# #### 5. Overall rating of each cuisines per location

# %%
pivot=data.pivot_table(values='Overall_Rating',index='Location',columns='Cuisines',aggfunc='sum')
pivot
# Out:
# Cuisines            Chinese  Filipino  French  Indian  Italian  Japanese  \
# Location
# Cedar Hill, NY          NaN       NaN     NaN     3.5      NaN       NaN
# Central Park,NY         7.0      10.5     7.5     2.5      5.0      13.0
# Central Park,ny         NaN       3.5     4.0    14.5      NaN       NaN
# China Town, NY          3.5       3.0     5.0    17.5      NaN       NaN
# Market City, MY         NaN       NaN     NaN     3.0      NaN       NaN
# Market City, NY         NaN       5.0     5.5     6.0      NaN      15.0
# Riverdale,NY            5.5       9.5     3.5     NaN     18.0      15.5
# St. George,NY          11.5      16.5    14.5    14.5      7.5      17.0
# Upper East Side,NY     18.5       6.5     7.5     3.0      3.5      17.0
# Upper West Side,NY      1.5       2.0     8.0     5.5      2.0       5.0
#
# Cuisines            Seafood
# Location
# Cedar Hill, NY          NaN
# Central Park,NY         4.0
# Central Park,ny         NaN
# ...

# %% [markdown]
# #### 6. Which cuisine is more popular in China Town, NY by its food rating

# %%
China_Town_NY=sort_location('China Town, NY')
China_Town_NY.query("Food_Rating>=3").sort_values(by='Food_Rating',ascending=False).Cuisines.value_counts()
# Out:
# Seafood    4
# Indian     2
# French     2
# Name: Cuisines, dtype: int64

# %% [markdown]
# #### 7. Age category of people using more alcohol and smokes

# %%
cutoff=[0,18,50,100]
labels=['Child','Adult','Old']
data['Age_type']=pd.cut(data.Age,bins=cutoff,labels=labels)
data.head()
# Out:
#              Location  Gender Marital_status      Activity  Budget  Cuisines  \
# 0  Upper East Side,NY  Female         Single  Professional       3  Japanese
# 1       St. George,NY  Female        Married       Student       3    Indian
# 2  Upper West Side,NY    Male         Single       Student       5   Seafood
# 3  Upper East Side,NY  Female        Married  Professional       5  Japanese
# 4     Central Park,NY    Male         Single       Student       4  Filipino
#
#     Alcohol    Smoker  Food_Rating  Service_Rating  Overall_Rating Often_A_S  \
# 0     Never     Never            5               4             4.5        No
# 1     Never  Socially            1               1             1.0        No
# 2     Often     Often            5               5             5.0       Yes
# 3     Never  Socially            3               1             2.0        No
# 4  Socially     Never            2               4             3.0        No
#
#    Age Age_type
# 0   16    Child
# ...

# %%
age_category_alco_smoke=data.query("Alcohol=='Socially' & Smoker=='Socially'")
age_category_alco_smoke.Age_type.value_counts()
# Out:
# Old      6
# Child    2
# Adult    2
# Name: Age_type, dtype: int64

# %% [markdown]
# ## Graphical EDA

# %% [markdown]
# ### Univariate analysis

# %%
sns.histplot(data=data,x='Food_Rating',kde=True, bins=5)
plt.show();

# %%
sns.histplot(data=data, x='Service_Rating',color='orange',kde=True,bins=5);

# %% [markdown]
# #### BOX PLOT

# %%
plt.figure(figsize=(4,6))
sns.boxplot(data=data,y='Food_Rating',color='brown')
plt.show();

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=30)
plt.subplot(3,2,1)
sns.boxplot(data=data,y='Food_Rating')

plt.subplot(3,2,2)
sns.boxplot(data=data,y='Budget')

plt.subplot(3,2,3)
sns.boxplot(data=data,y='Service_Rating')

plt.subplot(3,2,4)
sns.boxplot(data=data,y='Overall_Rating')

plt.subplot(3,2,5)
sns.boxplot(data=data,y='Age')

plt.show;

# %% [markdown]
# ### Multivariate analysis

# %% [markdown]
# #### COUNT PLOT

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation=90)
sns.countplot(data=data,x='Location')
plt.show;

# %% [markdown]
# St. George,NY is the most frequent location in the data set

# %%
plt.xticks(rotation=75)
sns.countplot(data=data,x='Location',hue='Gender')
plt.show;

# %% [markdown]
# In Upper East Side,NY, female customers are more than male customers who opting restuarants while male customers are more than female customers in other locations

# %%
plt.xticks(rotation=90)
sns.countplot(data=data,x='Location',hue='Cuisines')
plt.show;

# %%
plt.xticks(rotation=90)
sns.countplot(data=data,x='Location',hue='Overall_Rating')
plt.show();

# %%
sns.countplot(data=data,x='Cuisines')
plt.show();

# %%
sns.countplot(data=data,x='Cuisines',hue='Food_Rating')
plt.show();

# %%
sns.countplot(data=data,x='Gender',hue='Activity')
plt.show();

# %%
sns.countplot(data=data,x='Gender',hue='Alcohol')
plt.show();

# %%
sns.countplot(data=data,x='Gender',hue='Smoker')
plt.show();

# %%
sns.countplot(data=data,x='Gender',hue='Marital_status')
plt.show();

# %%
sns.countplot(data=data,x='Gender',hue='Often_A_S')
plt.show();

# %%
sns.countplot(data=data,x='Activity',hue='Often_A_S')
plt.show();

# %% [markdown]
# #### SUB PLOTS

# %%
plt.figure(figsize=(20,18))
plt.xticks(rotation=90)
plt.subplot(3,3,1)
sns.countplot(data=data,x='Cuisines',hue='Gender')

plt.subplot(3,3,2)
sns.countplot(data=data,x='Cuisines',hue='Alcohol')

plt.subplot(3,3,3)
sns.countplot(data=data,x='Cuisines',hue='Smoker')

plt.subplot(3,3,4)
sns.countplot(data=data,x='Cuisines',hue='Activity')

plt.subplot(3,3,5)
sns.countplot(data=data,x='Cuisines',hue='Marital_status')

plt.subplot(3,3,6)
sns.countplot(data=data,x='Cuisines',hue='Often_A_S')

plt.subplot(3,3,7)
sns.countplot(data=data,x='Cuisines',hue='Food_Rating')

plt.subplot(3,3,8)
sns.countplot(data=data,x='Cuisines',hue='Overall_Rating')

plt.show();

# %% [markdown]
# #### LINE PLOT

# %%
plt.figure(figsize=(6,4))
plt.xlabel('Cuisines')
plt.ylabel('Age')
plt.title('Cuisines vs Age')
sns.lineplot(data.Cuisines,data.Age,color='black')
plt.show()

# %%
Central_Park_NY=sort_location('Central Park,NY')
plt.xlabel('Cuisines')
plt.ylabel('Food_Rating')
plt.title('Cuisines vs Food_Rating')
sns.lineplot(data=Central_Park_NY,x='Cuisines',y='Food_Rating',color='purple')
plt.show();

# %% [markdown]
# #### BAR PLOT

# %%
plt.figure(figsize=(6,3))
plt.xticks(rotation=90)
sns.barplot(data=data,x='Gender',y='Age',hue='Smoker')
plt.show();

# %%
plt.figure(figsize=(6,3))
plt.xticks(rotation=90)
sns.barplot(data=data,x='Gender',y='Age',hue='Alcohol')
plt.show();

# %%
plt.figure(figsize=(6,3))
plt.xticks(rotation=90)
sns.barplot(data=data,x='Gender',y='Age',hue='Activity')
plt.show();

# %% [markdown]
# ### AREA CHART

# %%
plt.figure(figsize=(5,4))
plt.xticks(rotation=75)
plt.stackplot(Central_Park_NY.Cuisines,Central_Park_NY.Age)
plt.show();

# %%
plt.figure(figsize=(5,4))
plt.xticks(rotation=75)
plt.stackplot(Central_Park_NY.Cuisines,Central_Park_NY.Age,Central_Park_NY.Food_Rating)
plt.show();

# %% [markdown]
# #### HEAT MAP

# %%
sns.heatmap(data.corr(),annot=True)
plt.show();

# %%
sns.heatmap(data.corr()[['Overall_Rating']].sort_values(by='Overall_Rating'),annot=True,cmap='rainbow')
plt.show();

# %% [markdown]
# #### SCATTER PLOT

# %%
sns.scatterplot(data=data,x='Food_Rating',y='Overall_Rating')
plt.show();

# %%
sns.scatterplot(data=data,x='Age',y='Overall_Rating',hue='Service_Rating')
plt.show();

# %% [markdown]
# #### PIE CHART

# %%
data.Cuisines.value_counts()
# Out:
# Japanese    23
# Indian      22
# Filipino    19
# French      18
# Seafood     14
# Chinese     14
# Italian     11
# Name: Cuisines, dtype: int64

# %%
plt.pie(data=data,\
        x=data.Cuisines.value_counts(),\
        explode=[0.1,0,0,0,0,0,0],\
        colors=sns.color_palette('turbo'),\
        labels=['Japanese','Indian','Filipino','French','Seafood','Chinese','Italian'],\
       autopct='%1.2f%%')
plt.show();

# %%
data.groupby(['Gender'])['Budget'].sum()
# Out:
# Gender
# Female    191
# Male      275
# Name: Budget, dtype: int64

# %%
plt.pie(data=data,\
        x=data.groupby(['Gender'])['Budget'].sum(),\
        explode=[0.1,0],\
        labels=['Female','Male'],\
        colors=sns.color_palette('Pastel1'),\
        autopct='%1.2f%%');

# %% [markdown]
# #### CAT PLOT

# %%
sns.catplot(data=data,x='Marital_status',y='Budget',hue='Gender')
plt.show();

# %%
sns.catplot(data=data,x='Activity',y='Budget',hue='Gender')
plt.show();

# %%
In Professionals, females spent more budject

# %% [markdown]
# #### REG PLOT

# %%
sns.regplot(data=data,x='Service_Rating',y='Overall_Rating',color='black')
plt.show();

# %% [markdown]
# This graph shows a positive correlation between Service rating and overall rating

# %%
sns.regplot(data=data,x='Service_Rating',y='Food_Rating',color='green')
plt.show();

# %% [markdown]
# The graph shows nearly zero correlation between Service rating and food rating
